# %% [markdown]
# # Make noise to image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def add_gaussian_noise(image, mean=0, sigma=25):
    noise = np.random.normal(mean, sigma, image.shape).astype(np.float32)
    noisy_image = cv2.add(image.astype(np.float32), noise)
    return np.clip(noisy_image, 0, 255).astype(np.uint8)

# %%
image_path = "./sharp/7.jpg" 
original_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
gaussian_noisy = add_gaussian_noise(original_image)
cv2.imwrite("./noise/gaussian_noisy.jpg", gaussian_noisy)
# Out:
# True

# %% [markdown]
# # GA + Gaussian filter
# ## GA optimize the parameter of Gaussian filter

# %% [markdown]
# ### Function definition

# %%
import cv2
import numpy as np
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import mean_squared_error
import random

def calculate_psnr(original, blurred):
    mse = mean_squared_error(original, blurred)
    if mse == 0:
        return float("inf")  
    max_pixel = 255.0
    psnr = 20 * np.log10(max_pixel / np.sqrt(mse))
    return psnr

def create_gaussian_kernel(kernel_size, sigma):
    kernel_size = max(3, kernel_size | 1)  
    ax = np.linspace(-(kernel_size // 2), kernel_size // 2, kernel_size)
    xx, yy = np.meshgrid(ax, ax)
    kernel = np.exp(-(xx**2 + yy**2) / (2 * sigma**2))
    kernel /= np.sum(kernel)  
    return kernel

def apply_custom_gaussian_filter(image, kernel_size=5, sigma=1.0):
    kernel = create_gaussian_kernel(kernel_size, sigma)
    if len(image.shape) == 3:  
        filtered_image = np.zeros_like(image)
        for i in range(3): 
            filtered_image[:, :, i] = cv2.filter2D(image[:, :, i], -1, kernel)
    else: 
        filtered_image = cv2.filter2D(image, -1, kernel)
    return filtered_image

def fitness_function(original, image, params):
    kernel_size, sigma = int(params[0]), params[1]
    kernel_size = max(3, kernel_size | 1)
    filtered_image = apply_custom_gaussian_filter(image, kernel_size, sigma)
    return calculate_psnr(original, filtered_image), kernel_size, sigma

# %% [markdown]
# ### Only Gaussian filter

# %%
original = cv2.imread('./sharp/7.jpg', cv2.IMREAD_GRAYSCALE)
image = cv2.imread('./noise/gaussian_noisy.jpg', cv2.IMREAD_GRAYSCALE)
kernel_size = 7
sigma = 1.3
filtered_image = apply_custom_gaussian_filter(image, kernel_size, sigma)

psnr_value = psnr(image, filtered_image)
print(f"PSNR without GA: {psnr_value:.2f}")

cv2.imwrite('./result/only_Gaussian.jpg', filtered_image)
print("Filtered image saved as 'only_Gaussian.jpg'")
# Out:
# PSNR without GA: 20.57
# Filtered image saved as 'only_Gaussian.jpg'

# %% [markdown]
# ### GA to optimize the value

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)

original = cv2.imread('./sharp/7.jpg', cv2.IMREAD_GRAYSCALE)
image = cv2.imread('./noise/gaussian_noisy.jpg', cv2.IMREAD_GRAYSCALE)

population_size = 200
generations = 15
mutation_rate = 0.1

population = [(random.randint(3, 101) | 1, random.uniform(0.1, 3)) for _ in range(population_size)]

for gen in range(generations):
    print(f"\n--- Generation {gen + 1} ---")
    
    fitness_scores = []
    for individual in population:
        fitness, kernel, sigma = fitness_function(original, image, individual)
        fitness_scores.append(fitness)
        print(f"Tested Kernel Size: {kernel}, Sigma: {sigma:.2f}, PSNR: {fitness:.2f}")
    
    sorted_population = [x for _, x in sorted(zip(fitness_scores, population), reverse=True)]
    population = sorted_population[:population_size // 2]
    
    new_population = []
    while len(new_population) < population_size:
        parent1, parent2 = random.sample(population, 2)
        
        child = ((parent1[0] + parent2[0]) // 2, (parent1[1] + parent2[1]) / 2)
        
        if random.random() < mutation_rate:
            child = (child[0] + random.choice([-2, 2]), child[1] + random.uniform(-0.5, 0.5))
        
        child = (max(3, int(child[0]) | 1), max(0.1, child[1]))
        
        new_population.append(child)
    
    population = new_population
    best_fitness = max(fitness_scores)
    print(f"Best PSNR in Generation {gen + 1}: {best_fitness:.2f}")

best_params = sorted_population[0]
kernel_size_ga, sigma_ga = int(best_params[0]), best_params[1]
print(f"\nOptimized Parameters: Kernel Size = {kernel_size_ga}, Sigma = {sigma_ga:.2f}")

filtered_image_ga = apply_custom_gaussian_filter(image, kernel_size_ga, sigma_ga)
psnr_value_ga = calculate_psnr(original, filtered_image_ga)
print(f"PSNR with GA: {psnr_value_ga:.2f}")

cv2.imwrite('./result/GA_Gaussian.jpg', filtered_image_ga)
print("Filtered image saved as 'GA_Gaussian.jpg'")
# Out:
# --- Generation 1 ---
# Tested Kernel Size: 85, Sigma: 0.42, PSNR: 22.17
# Tested Kernel Size: 97, Sigma: 0.90, PSNR: 28.30
# Tested Kernel Size: 31, Sigma: 0.50, PSNR: 24.09
# Tested Kernel Size: 17, Sigma: 2.06, PSNR: 29.16
# Tested Kernel Size: 73, Sigma: 0.35, PSNR: 20.85
# Tested Kernel Size: 57, Sigma: 0.19, PSNR: 20.26
# Tested Kernel Size: 15, Sigma: 0.73, PSNR: 27.39
# Tested Kernel Size: 67, Sigma: 1.85, PSNR: 29.24
# Tested Kernel Size: 75, Sigma: 0.68, PSNR: 26.88
# Tested Kernel Size: 87, Sigma: 2.13, PSNR: 29.13
# Tested Kernel Size: 57, Sigma: 0.74, PSNR: 27.43
# Tested Kernel Size: 79, Sigma: 0.91, PSNR: 28.33
# Tested Kernel Size: 3, Sigma: 2.30, PSNR: 27.71
# Tested Kernel Size: 23, Sigma: 2.12, PSNR: 29.14
# Tested Kernel Size: 47, Sigma: 0.91, PSNR: 28.33
# Tested Kernel Size: 31, Sigma: 2.88, PSNR: 28.72
# Tested Kernel Size: 47, Sigma: 0.40, PSNR: 21.60
# Tested Kernel Size: 51, Sigma: 0.38, PSNR: 21.30
# Tested Kernel Size: 47, Sigma: 1.85, PSNR: 29.23
# Tested Kernel Size: 9, Sigma: 2.22, PSNR: 29.14
# Tested Kernel Size: 71, Sigma: 0.46, PSNR: 23.09
# Tested Kernel Size: 51, Sigma: 0.33, PSNR: 20.59
# Tested Kernel Size: 41, Sigma: 2.51, PSNR: 28.94
# Tested Kernel Size: 83, Sigma: 2.67, PSNR: 28.85
# Tested Kernel Size: 49, Sigma: 1.77, PSNR: 29.25
# Tested Kernel Size: 93, Sigma: 0.30, PSNR: 20.39
# Tested Kernel Size: 87, Sigma: 0.76, PSNR: 27.58
# Tested Kernel Size: 41, Sigma: 2.96, PSNR: 28.67
# Tested Kernel Size: 33, Sigma: 2.61, PSNR: 28.88
# Tested Kernel Size: 51, Sigma: 0.91, PSNR: 28.33
# Tested Kernel Size: 85, Sigma: 2.52, PSNR: 28.94
# Tested Kernel Size: 23, Sigma: 1.17, PSNR: 28.99
# Tested Kernel Size: 29, Sigma: 2.04, PSNR: 29.17
# Tested Kernel Size: 93, Sigma: 2.82, PSNR: 28.76
# Tested Kernel Size: 85, Sigma: 0.31, PSNR: 20.43
# Tested Kernel Size: 85, Sigma: 0.60, PSNR: 25.85
# Tested Kernel Size: 97, Sigma: 0.81, PSNR: 27.89
# Tested Kernel Size: 63, Sigma: 1.20, PSNR: 29.03
# Tested Kernel Size: 85, Sigma: 2.10, PSNR: 29.15
# Tested Kernel Size: 31, Sigma: 2.09, PSNR: 29.16
# Tested Kernel Size: 101, Sigma: 2.35, PSNR: 29.03
# Tested Kernel Size: 33, Sigma: 2.48, PSNR: 28.96
# Tested Kernel Size: 43, Sigma: 1.26, PSNR: 29.10
# Tested Kernel Size: 11, Sigma: 0.71, PSNR: 27.21
# Tested Kernel Size: 75, Sigma: 2.64, PSNR: 28.86
# Tested Kernel Size: 43, Sigma: 0.72, PSNR: 27.25
# Tested Kernel Size: 67, Sigma: 1.25, PSNR: 29.08
# Tested Kernel Size: 85, Sigma: 1.43, PSNR: 29.22
# Tested Kernel Size: 37, Sigma: 0.50, PSNR: 24.10
# Tested Kernel Size: 99, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 37, Sigma: 2.27, PSNR: 29.07
# Tested Kernel Size: 57, Sigma: 2.70, PSNR: 28.83
# Tested Kernel Size: 55, Sigma: 1.15, PSNR: 28.95
# Tested Kernel Size: 21, Sigma: 1.58, PSNR: 29.26
# Tested Kernel Size: 15, Sigma: 2.29, PSNR: 29.06
# Tested Kernel Size: 17, Sigma: 0.54, PSNR: 24.91
# Tested Kernel Size: 23, Sigma: 2.40, PSNR: 29.00
# Tested Kernel Size: 57, Sigma: 1.83, PSNR: 29.24
# Tested Kernel Size: 53, Sigma: 1.21, PSNR: 29.03
# Tested Kernel Size: 63, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 73, Sigma: 2.60, PSNR: 28.89
# Tested Kernel Size: 5, Sigma: 2.07, PSNR: 28.93
# Tested Kernel Size: 17, Sigma: 2.08, PSNR: 29.16
# Tested Kernel Size: 71, Sigma: 2.28, PSNR: 29.07
# Tested Kernel Size: 101, Sigma: 1.96, PSNR: 29.20
# Tested Kernel Size: 17, Sigma: 0.95, PSNR: 28.49
# Tested Kernel Size: 23, Sigma: 1.42, PSNR: 29.21
# Tested Kernel Size: 95, Sigma: 2.64, PSNR: 28.87
# Tested Kernel Size: 37, Sigma: 2.92, PSNR: 28.69
# Tested Kernel Size: 101, Sigma: 0.62, PSNR: 26.17
# Tested Kernel Size: 17, Sigma: 2.62, PSNR: 28.88
# Tested Kernel Size: 41, Sigma: 2.54, PSNR: 28.92
# Tested Kernel Size: 67, Sigma: 1.87, PSNR: 29.23
# Tested Kernel Size: 23, Sigma: 1.18, PSNR: 29.00
# Tested Kernel Size: 23, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 71, Sigma: 2.76, PSNR: 28.79
# Tested Kernel Size: 79, Sigma: 1.04, PSNR: 28.74
# Tested Kernel Size: 5, Sigma: 0.42, PSNR: 22.20
# Tested Kernel Size: 49, Sigma: 2.65, PSNR: 28.86
# Tested Kernel Size: 43, Sigma: 0.79, PSNR: 27.79
# Tested Kernel Size: 33, Sigma: 2.65, PSNR: 28.86
# Tested Kernel Size: 13, Sigma: 0.35, PSNR: 20.80
# Tested Kernel Size: 65, Sigma: 2.47, PSNR: 28.97
# Tested Kernel Size: 101, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 19, Sigma: 0.47, PSNR: 23.33
# Tested Kernel Size: 63, Sigma: 2.85, PSNR: 28.74
# Tested Kernel Size: 25, Sigma: 0.87, PSNR: 28.18
# Tested Kernel Size: 81, Sigma: 1.33, PSNR: 29.16
# Tested Kernel Size: 31, Sigma: 2.79, PSNR: 28.77
# Tested Kernel Size: 99, Sigma: 2.22, PSNR: 29.10
# Tested Kernel Size: 29, Sigma: 2.17, PSNR: 29.12
# Tested Kernel Size: 55, Sigma: 2.99, PSNR: 28.65
# Tested Kernel Size: 87, Sigma: 1.18, PSNR: 29.00
# Tested Kernel Size: 69, Sigma: 1.41, PSNR: 29.21
# Tested Kernel Size: 35, Sigma: 0.75, PSNR: 27.52
# Tested Kernel Size: 47, Sigma: 0.16, PSNR: 20.26
# Tested Kernel Size: 73, Sigma: 0.77, PSNR: 27.63
# Tested Kernel Size: 31, Sigma: 0.12, PSNR: 20.26
# Tested Kernel Size: 93, Sigma: 1.93, PSNR: 29.21
# Tested Kernel Size: 33, Sigma: 0.30, PSNR: 20.35
# Tested Kernel Size: 7, Sigma: 2.59, PSNR: 29.08
# Tested Kernel Size: 13, Sigma: 1.59, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 2.04, PSNR: 29.17
# Tested Kernel Size: 31, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 95, Sigma: 2.81, PSNR: 28.76
# Tested Kernel Size: 77, Sigma: 1.77, PSNR: 29.25
# Tested Kernel Size: 35, Sigma: 2.38, PSNR: 29.02
# Tested Kernel Size: 55, Sigma: 0.65, PSNR: 26.61
# Tested Kernel Size: 15, Sigma: 2.01, PSNR: 29.18
# Tested Kernel Size: 49, Sigma: 1.33, PSNR: 29.16
# Tested Kernel Size: 63, Sigma: 2.61, PSNR: 28.89
# Tested Kernel Size: 9, Sigma: 2.05, PSNR: 29.18
# Tested Kernel Size: 85, Sigma: 0.39, PSNR: 21.39
# Tested Kernel Size: 55, Sigma: 2.21, PSNR: 29.10
# Tested Kernel Size: 17, Sigma: 0.82, PSNR: 27.94
# Tested Kernel Size: 27, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 21, Sigma: 1.32, PSNR: 29.15
# Tested Kernel Size: 39, Sigma: 1.44, PSNR: 29.22
# Tested Kernel Size: 13, Sigma: 1.39, PSNR: 29.19
# Tested Kernel Size: 73, Sigma: 0.38, PSNR: 21.36
# Tested Kernel Size: 87, Sigma: 3.00, PSNR: 28.64
# Tested Kernel Size: 5, Sigma: 2.91, PSNR: 28.85
# Tested Kernel Size: 99, Sigma: 2.56, PSNR: 28.91
# Tested Kernel Size: 25, Sigma: 1.28, PSNR: 29.11
# Tested Kernel Size: 65, Sigma: 0.72, PSNR: 27.27
# Tested Kernel Size: 55, Sigma: 2.72, PSNR: 28.82
# Tested Kernel Size: 25, Sigma: 1.20, PSNR: 29.02
# Tested Kernel Size: 53, Sigma: 0.87, PSNR: 28.18
# Tested Kernel Size: 61, Sigma: 0.93, PSNR: 28.41
# Tested Kernel Size: 93, Sigma: 2.88, PSNR: 28.72
# Tested Kernel Size: 75, Sigma: 2.02, PSNR: 29.18
# Tested Kernel Size: 65, Sigma: 0.55, PSNR: 25.02
# Tested Kernel Size: 41, Sigma: 0.73, PSNR: 27.37
# Tested Kernel Size: 11, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 73, Sigma: 0.28, PSNR: 20.26
# Tested Kernel Size: 43, Sigma: 0.27, PSNR: 20.26
# Tested Kernel Size: 77, Sigma: 1.48, PSNR: 29.24
# Tested Kernel Size: 71, Sigma: 0.56, PSNR: 25.17
# Tested Kernel Size: 69, Sigma: 0.33, PSNR: 20.62
# Tested Kernel Size: 27, Sigma: 0.30, PSNR: 20.37
# Tested Kernel Size: 11, Sigma: 2.06, PSNR: 29.17
# Tested Kernel Size: 33, Sigma: 1.27, PSNR: 29.11
# Tested Kernel Size: 75, Sigma: 0.81, PSNR: 27.91
# Tested Kernel Size: 79, Sigma: 0.22, PSNR: 20.26
# Tested Kernel Size: 13, Sigma: 1.32, PSNR: 29.15
# Tested Kernel Size: 77, Sigma: 1.74, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 2.81, PSNR: 28.76
# Tested Kernel Size: 29, Sigma: 2.04, PSNR: 29.17
# Tested Kernel Size: 43, Sigma: 0.79, PSNR: 27.78
# Tested Kernel Size: 53, Sigma: 0.48, PSNR: 23.51
# Tested Kernel Size: 85, Sigma: 0.97, PSNR: 28.55
# Tested Kernel Size: 43, Sigma: 2.79, PSNR: 28.77
# Tested Kernel Size: 13, Sigma: 0.13, PSNR: 20.26
# Tested Kernel Size: 83, Sigma: 3.00, PSNR: 28.65
# Tested Kernel Size: 15, Sigma: 0.31, PSNR: 20.46
# Tested Kernel Size: 31, Sigma: 1.57, PSNR: 29.26
# Tested Kernel Size: 19, Sigma: 2.81, PSNR: 28.77
# Tested Kernel Size: 11, Sigma: 2.65, PSNR: 28.94
# Tested Kernel Size: 51, Sigma: 0.93, PSNR: 28.40
# Tested Kernel Size: 59, Sigma: 2.52, PSNR: 28.94
# Tested Kernel Size: 93, Sigma: 0.98, PSNR: 28.57
# Tested Kernel Size: 87, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 89, Sigma: 2.47, PSNR: 28.96
# Tested Kernel Size: 41, Sigma: 2.80, PSNR: 28.77
# Tested Kernel Size: 17, Sigma: 2.82, PSNR: 28.76
# Tested Kernel Size: 21, Sigma: 0.87, PSNR: 28.17
# Tested Kernel Size: 17, Sigma: 2.25, PSNR: 29.08
# Tested Kernel Size: 23, Sigma: 0.89, PSNR: 28.26
# Tested Kernel Size: 81, Sigma: 0.71, PSNR: 27.20
# Tested Kernel Size: 47, Sigma: 0.69, PSNR: 27.01
# Tested Kernel Size: 85, Sigma: 2.57, PSNR: 28.90
# Tested Kernel Size: 67, Sigma: 1.52, PSNR: 29.25
# Tested Kernel Size: 9, Sigma: 0.37, PSNR: 21.08
# Tested Kernel Size: 57, Sigma: 2.51, PSNR: 28.94
# Tested Kernel Size: 9, Sigma: 0.11, PSNR: 20.26
# Tested Kernel Size: 101, Sigma: 0.48, PSNR: 23.50
# Tested Kernel Size: 37, Sigma: 0.57, PSNR: 25.39
# Tested Kernel Size: 59, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 17, Sigma: 0.32, PSNR: 20.50
# Tested Kernel Size: 91, Sigma: 2.72, PSNR: 28.82
# Tested Kernel Size: 73, Sigma: 0.20, PSNR: 20.26
# Tested Kernel Size: 51, Sigma: 1.79, PSNR: 29.25
# Tested Kernel Size: 21, Sigma: 1.35, PSNR: 29.17
# Tested Kernel Size: 9, Sigma: 0.99, PSNR: 28.62
# Tested Kernel Size: 9, Sigma: 2.71, PSNR: 29.00
# Tested Kernel Size: 29, Sigma: 2.08, PSNR: 29.16
# Tested Kernel Size: 89, Sigma: 0.40, PSNR: 21.63
# Tested Kernel Size: 75, Sigma: 2.66, PSNR: 28.85
# Tested Kernel Size: 55, Sigma: 2.92, PSNR: 28.69
# Tested Kernel Size: 99, Sigma: 0.55, PSNR: 25.01
# Tested Kernel Size: 33, Sigma: 2.61, PSNR: 28.89
# Tested Kernel Size: 25, Sigma: 2.66, PSNR: 28.86
# Tested Kernel Size: 7, Sigma: 0.62, PSNR: 26.20
# Tested Kernel Size: 45, Sigma: 2.37, PSNR: 29.02
# Tested Kernel Size: 55, Sigma: 2.43, PSNR: 28.99
# Tested Kernel Size: 97, Sigma: 2.45, PSNR: 28.97
# Tested Kernel Size: 37, Sigma: 0.56, PSNR: 25.26
# Tested Kernel Size: 93, Sigma: 0.41, PSNR: 21.96
# Tested Kernel Size: 7, Sigma: 2.59, PSNR: 29.08
# Best PSNR in Generation 1: 29.26
#
# --- Generation 2 ---
# Tested Kernel Size: 97, Sigma: 1.94, PSNR: 29.21
# Tested Kernel Size: 15, Sigma: 1.96, PSNR: 29.20
# Tested Kernel Size: 55, Sigma: 1.57, PSNR: 29.26
# Tested Kernel Size: 25, Sigma: 1.81, PSNR: 29.24
# Tested Kernel Size: 25, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 33, Sigma: 1.91, PSNR: 29.22
# Tested Kernel Size: 59, Sigma: 1.85, PSNR: 29.23
# Tested Kernel Size: 45, Sigma: 1.91, PSNR: 29.22
# Tested Kernel Size: 31, Sigma: 1.85, PSNR: 29.23
# Tested Kernel Size: 61, Sigma: 1.77, PSNR: 29.25
# Tested Kernel Size: 65, Sigma: 2.15, PSNR: 29.13
# Tested Kernel Size: 57, Sigma: 1.49, PSNR: 29.24
# Tested Kernel Size: 55, Sigma: 1.30, PSNR: 29.13
# Tested Kernel Size: 79, Sigma: 2.28, PSNR: 29.07
# Tested Kernel Size: 13, Sigma: 1.83, PSNR: 29.24
# Tested Kernel Size: 43, Sigma: 1.61, PSNR: 29.26
# Tested Kernel Size: 23, Sigma: 2.20, PSNR: 29.11
# Tested Kernel Size: 59, Sigma: 2.21, PSNR: 29.10
# Tested Kernel Size: 37, Sigma: 1.30, PSNR: 29.14
# Tested Kernel Size: 37, Sigma: 2.09, PSNR: 29.15
# Tested Kernel Size: 7, Sigma: 2.14, PSNR: 29.16
# Tested Kernel Size: 51, Sigma: 2.17, PSNR: 29.12
# Tested Kernel Size: 25, Sigma: 1.84, PSNR: 29.24
# Tested Kernel Size: 23, Sigma: 2.05, PSNR: 29.17
# Tested Kernel Size: 73, Sigma: 2.45, PSNR: 28.97
# Tested Kernel Size: 37, Sigma: 1.92, PSNR: 29.22
# Tested Kernel Size: 67, Sigma: 1.30, PSNR: 29.14
# Tested Kernel Size: 71, Sigma: 2.25, PSNR: 29.08
# Tested Kernel Size: 47, Sigma: 1.62, PSNR: 29.26
# Tested Kernel Size: 67, Sigma: 1.41, PSNR: 29.21
# Tested Kernel Size: 97, Sigma: 1.94, PSNR: 29.21
# Tested Kernel Size: 23, Sigma: 1.84, PSNR: 29.24
# Tested Kernel Size: 31, Sigma: 2.96, PSNR: 28.67
# Tested Kernel Size: 55, Sigma: 1.30, PSNR: 29.13
# Tested Kernel Size: 71, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 2.17, PSNR: 29.12
# Tested Kernel Size: 29, Sigma: 2.65, PSNR: 28.86
# Tested Kernel Size: 31, Sigma: 2.56, PSNR: 28.91
# Tested Kernel Size: 49, Sigma: 1.90, PSNR: 29.22
# Tested Kernel Size: 51, Sigma: 1.60, PSNR: 29.26
# Tested Kernel Size: 9, Sigma: 2.18, PSNR: 29.15
# Tested Kernel Size: 7, Sigma: 2.33, PSNR: 29.12
# Tested Kernel Size: 77, Sigma: 1.82, PSNR: 29.24
# Tested Kernel Size: 51, Sigma: 1.95, PSNR: 29.21
# Tested Kernel Size: 67, Sigma: 2.48, PSNR: 28.96
# Tested Kernel Size: 21, Sigma: 2.33, PSNR: 29.04
# Tested Kernel Size: 57, Sigma: 2.45, PSNR: 28.97
# Tested Kernel Size: 25, Sigma: 2.33, PSNR: 29.04
# Tested Kernel Size: 27, Sigma: 2.35, PSNR: 29.03
# Tested Kernel Size: 37, Sigma: 2.40, PSNR: 29.00
# Tested Kernel Size: 63, Sigma: 1.49, PSNR: 29.24
# Tested Kernel Size: 11, Sigma: 2.06, PSNR: 29.17
# Tested Kernel Size: 61, Sigma: 1.46, PSNR: 29.23
# Tested Kernel Size: 51, Sigma: 1.76, PSNR: 29.25
# Tested Kernel Size: 69, Sigma: 1.84, PSNR: 29.24
# Tested Kernel Size: 27, Sigma: 1.82, PSNR: 29.24
# Tested Kernel Size: 41, Sigma: 2.54, PSNR: 28.92
# Tested Kernel Size: 69, Sigma: 2.14, PSNR: 29.13
# Tested Kernel Size: 87, Sigma: 1.96, PSNR: 29.20
# Tested Kernel Size: 25, Sigma: 2.35, PSNR: 29.03
# Tested Kernel Size: 39, Sigma: 1.82, PSNR: 29.24
# Tested Kernel Size: 57, Sigma: 1.83, PSNR: 29.24
# Tested Kernel Size: 59, Sigma: 2.13, PSNR: 29.14
# Tested Kernel Size: 39, Sigma: 1.96, PSNR: 29.20
# Tested Kernel Size: 23, Sigma: 2.31, PSNR: 29.05
# Tested Kernel Size: 41, Sigma: 2.23, PSNR: 29.09
# Tested Kernel Size: 53, Sigma: 1.47, PSNR: 29.23
# Tested Kernel Size: 63, Sigma: 2.31, PSNR: 29.05
# Tested Kernel Size: 81, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 37, Sigma: 2.05, PSNR: 29.17
# Tested Kernel Size: 25, Sigma: 2.13, PSNR: 29.14
# Tested Kernel Size: 29, Sigma: 1.96, PSNR: 29.20
# Tested Kernel Size: 19, Sigma: 2.13, PSNR: 29.14
# Tested Kernel Size: 59, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 1.95, PSNR: 29.21
# Tested Kernel Size: 17, Sigma: 1.46, PSNR: 29.23
# Tested Kernel Size: 13, Sigma: 2.24, PSNR: 29.09
# Tested Kernel Size: 31, Sigma: 1.85, PSNR: 29.23
# Tested Kernel Size: 71, Sigma: 1.39, PSNR: 29.20
# Tested Kernel Size: 45, Sigma: 2.03, PSNR: 29.18
# Tested Kernel Size: 39, Sigma: 2.06, PSNR: 29.17
# Tested Kernel Size: 51, Sigma: 2.34, PSNR: 29.04
# Tested Kernel Size: 83, Sigma: 2.56, PSNR: 28.92
# Tested Kernel Size: 37, Sigma: 2.38, PSNR: 29.01
# Tested Kernel Size: 69, Sigma: 2.17, PSNR: 29.12
# Tested Kernel Size: 19, Sigma: 2.19, PSNR: 29.11
# Tested Kernel Size: 75, Sigma: 1.83, PSNR: 29.24
# Tested Kernel Size: 37, Sigma: 2.26, PSNR: 29.08
# Tested Kernel Size: 21, Sigma: 2.36, PSNR: 29.02
# Tested Kernel Size: 39, Sigma: 2.12, PSNR: 29.14
# Tested Kernel Size: 21, Sigma: 2.19, PSNR: 29.11
# Tested Kernel Size: 71, Sigma: 2.37, PSNR: 29.02
# Tested Kernel Size: 57, Sigma: 2.50, PSNR: 28.95
# Tested Kernel Size: 29, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 27, Sigma: 1.91, PSNR: 29.22
# Tested Kernel Size: 35, Sigma: 2.60, PSNR: 28.89
# Tested Kernel Size: 43, Sigma: 2.25, PSNR: 29.08
# Tested Kernel Size: 35, Sigma: 2.29, PSNR: 29.06
# Tested Kernel Size: 21, Sigma: 2.64, PSNR: 28.86
# Tested Kernel Size: 59, Sigma: 2.42, PSNR: 28.99
# Tested Kernel Size: 33, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 31, Sigma: 1.80, PSNR: 29.24
# Tested Kernel Size: 25, Sigma: 2.33, PSNR: 29.04
# Tested Kernel Size: 19, Sigma: 2.28, PSNR: 29.07
# Tested Kernel Size: 59, Sigma: 1.42, PSNR: 29.21
# Tested Kernel Size: 27, Sigma: 1.87, PSNR: 29.23
# Tested Kernel Size: 35, Sigma: 2.06, PSNR: 29.16
# Tested Kernel Size: 69, Sigma: 2.53, PSNR: 28.93
# Tested Kernel Size: 57, Sigma: 1.42, PSNR: 29.21
# Tested Kernel Size: 93, Sigma: 1.58, PSNR: 29.26
# Tested Kernel Size: 25, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 47, Sigma: 2.31, PSNR: 29.05
# Tested Kernel Size: 25, Sigma: 2.45, PSNR: 28.97
# Tested Kernel Size: 59, Sigma: 1.60, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.93, PSNR: 29.21
# Tested Kernel Size: 71, Sigma: 2.47, PSNR: 28.96
# Tested Kernel Size: 35, Sigma: 2.38, PSNR: 29.01
# Tested Kernel Size: 49, Sigma: 2.52, PSNR: 28.94
# Tested Kernel Size: 41, Sigma: 2.59, PSNR: 28.89
# Tested Kernel Size: 45, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 43, Sigma: 2.51, PSNR: 28.94
# Tested Kernel Size: 77, Sigma: 1.42, PSNR: 29.21
# Tested Kernel Size: 31, Sigma: 2.33, PSNR: 29.04
# Tested Kernel Size: 47, Sigma: 2.51, PSNR: 28.94
# Tested Kernel Size: 81, Sigma: 1.58, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.59, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 2.49, PSNR: 28.95
# Tested Kernel Size: 23, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 2.19, PSNR: 29.11
# Tested Kernel Size: 25, Sigma: 2.47, PSNR: 28.96
# Tested Kernel Size: 25, Sigma: 1.41, PSNR: 29.21
# Tested Kernel Size: 69, Sigma: 1.76, PSNR: 29.25
# Tested Kernel Size: 45, Sigma: 1.81, PSNR: 29.24
# Tested Kernel Size: 61, Sigma: 2.03, PSNR: 29.18
# Tested Kernel Size: 19, Sigma: 1.44, PSNR: 29.22
# Tested Kernel Size: 11, Sigma: 2.00, PSNR: 29.19
# Tested Kernel Size: 47, Sigma: 1.96, PSNR: 29.20
# Tested Kernel Size: 79, Sigma: 1.55, PSNR: 29.25
# Tested Kernel Size: 13, Sigma: 2.23, PSNR: 29.09
# Tested Kernel Size: 57, Sigma: 2.26, PSNR: 29.08
# Tested Kernel Size: 13, Sigma: 2.39, PSNR: 29.02
# Tested Kernel Size: 63, Sigma: 2.69, PSNR: 28.84
# Tested Kernel Size: 61, Sigma: 1.95, PSNR: 29.20
# Tested Kernel Size: 65, Sigma: 1.98, PSNR: 29.20
# Tested Kernel Size: 31, Sigma: 2.01, PSNR: 29.18
# Tested Kernel Size: 39, Sigma: 3.02, PSNR: 28.63
# Tested Kernel Size: 77, Sigma: 2.48, PSNR: 28.96
# Tested Kernel Size: 75, Sigma: 2.07, PSNR: 29.16
# Tested Kernel Size: 57, Sigma: 2.30, PSNR: 29.05
# Tested Kernel Size: 33, Sigma: 2.24, PSNR: 29.09
# Tested Kernel Size: 71, Sigma: 2.55, PSNR: 28.92
# Tested Kernel Size: 49, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 2.32, PSNR: 29.05
# Tested Kernel Size: 57, Sigma: 2.20, PSNR: 29.10
# Tested Kernel Size: 83, Sigma: 1.49, PSNR: 29.24
# Tested Kernel Size: 97, Sigma: 2.43, PSNR: 28.99
# Tested Kernel Size: 67, Sigma: 2.33, PSNR: 29.04
# Tested Kernel Size: 27, Sigma: 2.30, PSNR: 29.06
# Tested Kernel Size: 41, Sigma: 2.65, PSNR: 28.86
# Tested Kernel Size: 43, Sigma: 1.86, PSNR: 29.23
# Tested Kernel Size: 35, Sigma: 1.74, PSNR: 29.26
# Tested Kernel Size: 71, Sigma: 2.36, PSNR: 29.02
# Tested Kernel Size: 35, Sigma: 1.92, PSNR: 29.22
# Tested Kernel Size: 65, Sigma: 1.33, PSNR: 29.16
# Tested Kernel Size: 75, Sigma: 1.59, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 37, Sigma: 1.96, PSNR: 29.20
# Tested Kernel Size: 19, Sigma: 2.08, PSNR: 29.16
# Tested Kernel Size: 49, Sigma: 1.55, PSNR: 29.25
# Tested Kernel Size: 45, Sigma: 1.24, PSNR: 29.07
# Tested Kernel Size: 93, Sigma: 2.08, PSNR: 29.16
# Tested Kernel Size: 23, Sigma: 2.05, PSNR: 29.17
# Tested Kernel Size: 55, Sigma: 1.86, PSNR: 29.23
# Tested Kernel Size: 19, Sigma: 1.50, PSNR: 29.24
# Tested Kernel Size: 41, Sigma: 1.92, PSNR: 29.22
# Tested Kernel Size: 45, Sigma: 2.44, PSNR: 28.98
# Tested Kernel Size: 73, Sigma: 2.49, PSNR: 28.95
# Tested Kernel Size: 65, Sigma: 2.23, PSNR: 29.09
# Tested Kernel Size: 25, Sigma: 2.03, PSNR: 29.18
# Tested Kernel Size: 75, Sigma: 1.87, PSNR: 29.23
# Tested Kernel Size: 11, Sigma: 2.21, PSNR: 29.11
# Tested Kernel Size: 43, Sigma: 1.91, PSNR: 29.22
# Tested Kernel Size: 37, Sigma: 2.33, PSNR: 29.04
# Tested Kernel Size: 55, Sigma: 2.27, PSNR: 29.07
# Tested Kernel Size: 41, Sigma: 2.11, PSNR: 29.14
# Tested Kernel Size: 65, Sigma: 1.83, PSNR: 29.24
# Tested Kernel Size: 45, Sigma: 1.55, PSNR: 29.25
# Tested Kernel Size: 37, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 2.20, PSNR: 29.10
# Tested Kernel Size: 31, Sigma: 2.33, PSNR: 29.04
# Tested Kernel Size: 77, Sigma: 2.44, PSNR: 28.98
# Tested Kernel Size: 47, Sigma: 1.89, PSNR: 29.22
# Tested Kernel Size: 47, Sigma: 1.80, PSNR: 29.25
# Tested Kernel Size: 37, Sigma: 1.92, PSNR: 29.22
# Tested Kernel Size: 67, Sigma: 1.38, PSNR: 29.19
# Tested Kernel Size: 17, Sigma: 1.61, PSNR: 29.26
# Tested Kernel Size: 21, Sigma: 2.30, PSNR: 29.06
# Tested Kernel Size: 49, Sigma: 2.18, PSNR: 29.12
# Tested Kernel Size: 69, Sigma: 2.00, PSNR: 29.19
# Best PSNR in Generation 2: 29.26
#
# --- Generation 3 ---
# Tested Kernel Size: 35, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 77, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.53, PSNR: 29.25
# Tested Kernel Size: 41, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 65, Sigma: 1.91, PSNR: 29.22
# Tested Kernel Size: 63, Sigma: 1.79, PSNR: 29.25
# Tested Kernel Size: 45, Sigma: 1.82, PSNR: 29.24
# Tested Kernel Size: 61, Sigma: 2.26, PSNR: 29.08
# Tested Kernel Size: 49, Sigma: 1.89, PSNR: 29.23
# Tested Kernel Size: 39, Sigma: 1.98, PSNR: 29.19
# Tested Kernel Size: 35, Sigma: 1.42, PSNR: 29.21
# Tested Kernel Size: 53, Sigma: 1.90, PSNR: 29.22
# Tested Kernel Size: 15, Sigma: 1.83, PSNR: 29.24
# Tested Kernel Size: 41, Sigma: 1.83, PSNR: 29.24
# Tested Kernel Size: 39, Sigma: 1.53, PSNR: 29.25
# Tested Kernel Size: 29, Sigma: 1.53, PSNR: 29.25
# Tested Kernel Size: 49, Sigma: 1.85, PSNR: 29.23
# Tested Kernel Size: 39, Sigma: 1.89, PSNR: 29.22
# Tested Kernel Size: 65, Sigma: 1.55, PSNR: 29.25
# Tested Kernel Size: 61, Sigma: 1.90, PSNR: 29.22
# Tested Kernel Size: 41, Sigma: 1.86, PSNR: 29.23
# Tested Kernel Size: 59, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.85, PSNR: 29.24
# Tested Kernel Size: 41, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 63, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.47, PSNR: 29.23
# Tested Kernel Size: 15, Sigma: 1.89, PSNR: 29.22
# Tested Kernel Size: 29, Sigma: 1.90, PSNR: 29.22
# Tested Kernel Size: 29, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 25, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 75, Sigma: 1.38, PSNR: 29.19
# Tested Kernel Size: 61, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.79, PSNR: 29.25
# Tested Kernel Size: 39, Sigma: 1.94, PSNR: 29.21
# Tested Kernel Size: 37, Sigma: 1.89, PSNR: 29.22
# Tested Kernel Size: 57, Sigma: 1.86, PSNR: 29.23
# Tested Kernel Size: 43, Sigma: 2.04, PSNR: 29.17
# Tested Kernel Size: 73, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 41, Sigma: 1.49, PSNR: 29.24
# Tested Kernel Size: 25, Sigma: 1.93, PSNR: 29.21
# Tested Kernel Size: 81, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.88, PSNR: 29.23
# Tested Kernel Size: 49, Sigma: 1.53, PSNR: 29.25
# Tested Kernel Size: 61, Sigma: 1.87, PSNR: 29.23
# Tested Kernel Size: 53, Sigma: 1.71, PSNR: 29.26
# Tested Kernel Size: 87, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.58, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 33, Sigma: 1.76, PSNR: 29.25
# Tested Kernel Size: 61, Sigma: 1.74, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 37, Sigma: 1.90, PSNR: 29.22
# Tested Kernel Size: 61, Sigma: 1.49, PSNR: 29.24
# Tested Kernel Size: 55, Sigma: 1.80, PSNR: 29.25
# Tested Kernel Size: 81, Sigma: 1.45, PSNR: 29.23
# Tested Kernel Size: 31, Sigma: 2.28, PSNR: 29.07
# Tested Kernel Size: 51, Sigma: 1.89, PSNR: 29.22
# Tested Kernel Size: 59, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 23, Sigma: 1.87, PSNR: 29.23
# Tested Kernel Size: 43, Sigma: 1.86, PSNR: 29.23
# Tested Kernel Size: 59, Sigma: 1.86, PSNR: 29.23
# Tested Kernel Size: 39, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 75, Sigma: 1.71, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.52, PSNR: 29.25
# Tested Kernel Size: 41, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 25, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.61, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.86, PSNR: 29.23
# Tested Kernel Size: 29, Sigma: 1.59, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.88, PSNR: 29.23
# Tested Kernel Size: 71, Sigma: 1.28, PSNR: 29.12
# Tested Kernel Size: 51, Sigma: 1.56, PSNR: 29.25
# Tested Kernel Size: 41, Sigma: 1.74, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 79, Sigma: 1.98, PSNR: 29.19
# Tested Kernel Size: 51, Sigma: 1.87, PSNR: 29.23
# Tested Kernel Size: 41, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 39, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 73, Sigma: 1.87, PSNR: 29.23
# Tested Kernel Size: 43, Sigma: 1.81, PSNR: 29.24
# Tested Kernel Size: 19, Sigma: 1.87, PSNR: 29.23
# Tested Kernel Size: 33, Sigma: 1.95, PSNR: 29.21
# Tested Kernel Size: 57, Sigma: 1.53, PSNR: 29.25
# Tested Kernel Size: 51, Sigma: 1.81, PSNR: 29.24
# Tested Kernel Size: 41, Sigma: 1.94, PSNR: 29.21
# Tested Kernel Size: 41, Sigma: 2.15, PSNR: 29.13
# Tested Kernel Size: 71, Sigma: 1.92, PSNR: 29.22
# Tested Kernel Size: 23, Sigma: 1.56, PSNR: 29.25
# Tested Kernel Size: 59, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.95, PSNR: 29.20
# Tested Kernel Size: 57, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 51, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.93, PSNR: 29.21
# Tested Kernel Size: 55, Sigma: 1.49, PSNR: 29.24
# Tested Kernel Size: 63, Sigma: 2.01, PSNR: 29.19
# Tested Kernel Size: 45, Sigma: 1.82, PSNR: 29.24
# Tested Kernel Size: 35, Sigma: 1.82, PSNR: 29.24
# Tested Kernel Size: 51, Sigma: 1.87, PSNR: 29.23
# Tested Kernel Size: 67, Sigma: 1.71, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.88, PSNR: 29.23
# Tested Kernel Size: 61, Sigma: 1.77, PSNR: 29.25
# Tested Kernel Size: 21, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 25, Sigma: 2.05, PSNR: 29.17
# Tested Kernel Size: 63, Sigma: 1.52, PSNR: 29.25
# Tested Kernel Size: 67, Sigma: 1.45, PSNR: 29.23
# Tested Kernel Size: 33, Sigma: 1.85, PSNR: 29.24
# Tested Kernel Size: 49, Sigma: 1.96, PSNR: 29.20
# Tested Kernel Size: 51, Sigma: 1.83, PSNR: 29.24
# Tested Kernel Size: 63, Sigma: 1.62, PSNR: 29.26
# Tested Kernel Size: 27, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.94, PSNR: 29.21
# Tested Kernel Size: 57, Sigma: 1.54, PSNR: 29.25
# Tested Kernel Size: 55, Sigma: 1.71, PSNR: 29.26
# Tested Kernel Size: 27, Sigma: 1.60, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.74, PSNR: 29.26
# Tested Kernel Size: 67, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.80, PSNR: 29.25
# Tested Kernel Size: 17, Sigma: 1.96, PSNR: 29.20
# Tested Kernel Size: 61, Sigma: 1.83, PSNR: 29.24
# Tested Kernel Size: 71, Sigma: 1.57, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.77, PSNR: 29.25
# Tested Kernel Size: 31, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.86, PSNR: 29.23
# Tested Kernel Size: 59, Sigma: 1.93, PSNR: 29.21
# Tested Kernel Size: 61, Sigma: 1.07, PSNR: 28.81
# Tested Kernel Size: 41, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 57, Sigma: 1.91, PSNR: 29.22
# Tested Kernel Size: 35, Sigma: 1.46, PSNR: 29.23
# Tested Kernel Size: 31, Sigma: 1.98, PSNR: 29.19
# Tested Kernel Size: 35, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 85, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 2.38, PSNR: 29.01
# Tested Kernel Size: 53, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.91, PSNR: 29.22
# Tested Kernel Size: 61, Sigma: 1.81, PSNR: 29.24
# Tested Kernel Size: 47, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 51, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.89, PSNR: 29.22
# Tested Kernel Size: 29, Sigma: 1.84, PSNR: 29.24
# Tested Kernel Size: 65, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 51, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.98, PSNR: 29.20
# Tested Kernel Size: 51, Sigma: 1.40, PSNR: 29.20
# Tested Kernel Size: 55, Sigma: 1.92, PSNR: 29.22
# Tested Kernel Size: 21, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 2.13, PSNR: 29.13
# Tested Kernel Size: 43, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.80, PSNR: 29.25
# Tested Kernel Size: 37, Sigma: 1.92, PSNR: 29.22
# Tested Kernel Size: 51, Sigma: 1.77, PSNR: 29.25
# Tested Kernel Size: 61, Sigma: 1.77, PSNR: 29.25
# Tested Kernel Size: 69, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.76, PSNR: 29.25
# Tested Kernel Size: 85, Sigma: 1.82, PSNR: 29.24
# Tested Kernel Size: 43, Sigma: 2.01, PSNR: 29.19
# Tested Kernel Size: 41, Sigma: 1.74, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 73, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.89, PSNR: 29.22
# Tested Kernel Size: 35, Sigma: 1.79, PSNR: 29.25
# Tested Kernel Size: 21, Sigma: 1.82, PSNR: 29.24
# Tested Kernel Size: 27, Sigma: 1.83, PSNR: 29.24
# Tested Kernel Size: 59, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.82, PSNR: 29.24
# Tested Kernel Size: 41, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 41, Sigma: 1.87, PSNR: 29.23
# Tested Kernel Size: 41, Sigma: 1.85, PSNR: 29.23
# Tested Kernel Size: 57, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.93, PSNR: 29.21
# Tested Kernel Size: 55, Sigma: 1.54, PSNR: 29.25
# Tested Kernel Size: 47, Sigma: 1.46, PSNR: 29.23
# Tested Kernel Size: 43, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.92, PSNR: 29.22
# Tested Kernel Size: 47, Sigma: 1.84, PSNR: 29.24
# Tested Kernel Size: 37, Sigma: 1.86, PSNR: 29.23
# Tested Kernel Size: 71, Sigma: 0.97, PSNR: 28.54
# Tested Kernel Size: 69, Sigma: 1.51, PSNR: 29.24
# Tested Kernel Size: 43, Sigma: 1.81, PSNR: 29.24
# Tested Kernel Size: 45, Sigma: 1.95, PSNR: 29.20
# Tested Kernel Size: 51, Sigma: 1.55, PSNR: 29.25
# Tested Kernel Size: 79, Sigma: 1.53, PSNR: 29.25
# Tested Kernel Size: 77, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.56, PSNR: 29.25
# Tested Kernel Size: 51, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 2.00, PSNR: 29.19
# Tested Kernel Size: 23, Sigma: 1.79, PSNR: 29.25
# Tested Kernel Size: 33, Sigma: 1.56, PSNR: 29.25
# Tested Kernel Size: 63, Sigma: 1.80, PSNR: 29.25
# Tested Kernel Size: 35, Sigma: 1.60, PSNR: 29.26
# Tested Kernel Size: 67, Sigma: 1.59, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.98, PSNR: 29.20
# Tested Kernel Size: 31, Sigma: 1.80, PSNR: 29.25
# Tested Kernel Size: 49, Sigma: 2.00, PSNR: 29.19
# Tested Kernel Size: 57, Sigma: 1.71, PSNR: 29.26
# Best PSNR in Generation 3: 29.26
#
# --- Generation 4 ---
# Tested Kernel Size: 63, Sigma: 1.79, PSNR: 29.25
# Tested Kernel Size: 61, Sigma: 1.60, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 31, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.62, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 57, Sigma: 1.76, PSNR: 29.25
# Tested Kernel Size: 57, Sigma: 1.74, PSNR: 29.25
# Tested Kernel Size: 41, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.62, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 37, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 71, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.91, PSNR: 29.22
# Tested Kernel Size: 63, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 31, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 33, Sigma: 1.84, PSNR: 29.24
# Tested Kernel Size: 43, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.28, PSNR: 29.11
# Tested Kernel Size: 51, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 55, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.83, PSNR: 29.24
# Tested Kernel Size: 51, Sigma: 1.85, PSNR: 29.23
# Tested Kernel Size: 81, Sigma: 1.59, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.74, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.74, PSNR: 29.26
# Tested Kernel Size: 67, Sigma: 1.60, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 65, Sigma: 1.20, PSNR: 29.03
# Tested Kernel Size: 23, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 67, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 67, Sigma: 1.71, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.58, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 35, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.55, PSNR: 29.25
# Tested Kernel Size: 57, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 73, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.62, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.71, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.53, PSNR: 29.25
# Tested Kernel Size: 49, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.77, PSNR: 29.25
# Tested Kernel Size: 49, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.77, PSNR: 29.25
# Tested Kernel Size: 59, Sigma: 1.57, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.81, PSNR: 29.24
# Tested Kernel Size: 43, Sigma: 1.48, PSNR: 29.24
# Tested Kernel Size: 33, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 63, Sigma: 1.76, PSNR: 29.25
# Tested Kernel Size: 61, Sigma: 1.71, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 63, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 31, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.37, PSNR: 29.18
# Tested Kernel Size: 43, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 69, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 35, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.61, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 55, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 31, Sigma: 1.59, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.76, PSNR: 29.25
# Tested Kernel Size: 49, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 63, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 65, Sigma: 1.71, PSNR: 29.26
# Tested Kernel Size: 35, Sigma: 1.79, PSNR: 29.25
# Tested Kernel Size: 51, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 37, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 57, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 69, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.76, PSNR: 29.25
# Tested Kernel Size: 65, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.93, PSNR: 29.21
# Tested Kernel Size: 63, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 49, Sigma: 1.74, PSNR: 29.26
# Tested Kernel Size: 69, Sigma: 1.56, PSNR: 29.25
# Tested Kernel Size: 41, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.74, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 35, Sigma: 1.60, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.74, PSNR: 29.25
# Tested Kernel Size: 53, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.61, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 1.33, PSNR: 29.15
# Tested Kernel Size: 51, Sigma: 1.79, PSNR: 29.25
# Tested Kernel Size: 41, Sigma: 1.61, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 69, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 39, Sigma: 1.76, PSNR: 29.25
# Tested Kernel Size: 69, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.62, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 55, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 37, Sigma: 1.74, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.71, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 31, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 51, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.62, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 71, Sigma: 1.71, PSNR: 29.26
# Tested Kernel Size: 65, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 35, Sigma: 1.53, PSNR: 29.25
# Tested Kernel Size: 27, Sigma: 1.71, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.62, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.76, PSNR: 29.25
# Tested Kernel Size: 51, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 2.00, PSNR: 29.19
# Tested Kernel Size: 47, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 67, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.57, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.74, PSNR: 29.26
# Tested Kernel Size: 73, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 37, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 37, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.79, PSNR: 29.25
# Tested Kernel Size: 59, Sigma: 1.75, PSNR: 29.25
# Tested Kernel Size: 41, Sigma: 1.76, PSNR: 29.25
# Tested Kernel Size: 53, Sigma: 1.74, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 65, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.23, PSNR: 29.06
# Tested Kernel Size: 71, Sigma: 1.53, PSNR: 29.25
# Tested Kernel Size: 33, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.61, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.58, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.76, PSNR: 29.25
# Tested Kernel Size: 61, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.71, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.74, PSNR: 29.25
# Tested Kernel Size: 61, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.74, PSNR: 29.25
# Tested Kernel Size: 47, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.76, PSNR: 29.25
# Tested Kernel Size: 55, Sigma: 1.74, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.55, PSNR: 29.25
# Tested Kernel Size: 45, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 1.72, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.51, PSNR: 29.24
# Tested Kernel Size: 51, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.62, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 1.56, PSNR: 29.25
# Tested Kernel Size: 39, Sigma: 1.79, PSNR: 29.25
# Tested Kernel Size: 49, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.56, PSNR: 29.25
# Best PSNR in Generation 4: 29.26
#
# --- Generation 5 ---
# Tested Kernel Size: 45, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 73, Sigma: 1.92, PSNR: 29.22
# Tested Kernel Size: 51, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 69, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.62, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.60, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 33, Sigma: 1.59, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.23, PSNR: 29.06
# Tested Kernel Size: 49, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 65, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.62, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.99, PSNR: 29.19
# Tested Kernel Size: 51, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.32, PSNR: 29.15
# Tested Kernel Size: 55, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 67, Sigma: 1.61, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.61, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.41, PSNR: 29.21
# Tested Kernel Size: 47, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 67, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 2.06, PSNR: 29.17
# Tested Kernel Size: 57, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 39, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.88, PSNR: 29.23
# Tested Kernel Size: 45, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 65, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 43, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 69, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 67, Sigma: 1.57, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.19, PSNR: 29.01
# Tested Kernel Size: 53, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 65, Sigma: 1.69, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 37, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 35, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.62, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.53, PSNR: 29.25
# Tested Kernel Size: 45, Sigma: 1.86, PSNR: 29.23
# Tested Kernel Size: 53, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 41, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.61, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 65, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 59, Sigma: 1.20, PSNR: 29.03
# Tested Kernel Size: 51, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 63, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 47, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.67, PSNR: 29.26
# Tested Kernel Size: 71, Sigma: 1.29, PSNR: 29.12
# Tested Kernel Size: 77, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 51, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 49, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 45, Sigma: 1.58, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.62, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.66, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.68, PSNR: 29.26
# Tested Kernel Size: 61, Sigma: 1.54, PSNR: 29.25
# ...
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 53, Sigma: 1.78, PSNR: 29.25
# Tested Kernel Size: 53, Sigma: 1.40, PSNR: 29.20
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.33, PSNR: 29.16
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.92, PSNR: 29.21
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.28, PSNR: 29.12
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.54, PSNR: 29.25
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.60, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.24, PSNR: 29.08
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.31, PSNR: 29.14
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 2.12, PSNR: 29.14
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.50, PSNR: 29.24
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.46, PSNR: 29.23
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.16, PSNR: 28.97
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Best PSNR in Generation 14: 29.26
#
# --- Generation 15 ---
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 2.05, PSNR: 29.17
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.73, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.64, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.70, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 2.05, PSNR: 29.17
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.95, PSNR: 29.21
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.54, PSNR: 29.25
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.39, PSNR: 29.20
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.60, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 2.13, PSNR: 29.13
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.98, PSNR: 29.20
# Tested Kernel Size: 53, Sigma: 1.63, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 2.04, PSNR: 29.17
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.54, PSNR: 29.25
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.55, PSNR: 29.25
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 2.06, PSNR: 29.16
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 57, Sigma: 1.42, PSNR: 29.21
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.45, PSNR: 29.22
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 53, Sigma: 1.80, PSNR: 29.25
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Tested Kernel Size: 55, Sigma: 1.65, PSNR: 29.26
# Best PSNR in Generation 15: 29.26
#
# Optimized Parameters: Kernel Size = 55, Sigma = 1.65
# PSNR with GA: 29.26
# Filtered image saved as 'GA_Gaussian.jpg'

# %% [markdown]
# # Comparison

# %%
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import mean_squared_error
from scipy.signal import correlate2d
from skimage.filters import sobel

def calculate_ssim(original, blurred):
    return ssim(original, blurred, data_range=blurred.max() - blurred.min())

def calculate_mse(original, blurred):
    return mean_squared_error(original, blurred)

def calculate_ncc(original, blurred):
    original_normalized = original - np.mean(original)
    blurred_normalized = blurred - np.mean(blurred)
    
    numerator = np.sum(original_normalized * blurred_normalized)
    denominator = np.sqrt(np.sum(original_normalized**2) * np.sum(blurred_normalized**2))
    
    if denominator == 0:
        return 0
        
    return numerator / denominator

def calculate_gmsd(original, blurred):
    gradient_original = sobel(original)
    gradient_blurred = sobel(blurred)
    gmsd = np.sqrt(np.mean((gradient_original - gradient_blurred) ** 2))
    return gmsd

def calculate_vif(original, blurred):
    if np.array_equal(original, blurred):
        return 1.0
        
    gradient_original = np.gradient(original.astype(float))
    gradient_blurred = np.gradient(blurred.astype(float))
    sigma_nsq = 2  
    
    vif_score = 0
    total_variance = 0
    for grad_o, grad_b in zip(gradient_original, gradient_blurred):
        numerator = np.var(grad_o)
        denominator = np.var(grad_o - grad_b) + sigma_nsq
        vif_score += np.sum(numerator / denominator)
        total_variance += np.sum(numerator)  
    
    return vif_score / (total_variance + 1e-10)  

def calculate_fsim(original, blurred):
    pc1 = sobel(original).astype(np.float32)
    pc2 = sobel(blurred).astype(np.float32)
    t1 = np.minimum(pc1, pc2)
    t2 = np.maximum(pc1, pc2)
    fsim = np.sum(t1) / np.sum(t2)
    return fsim

# %% [markdown]
# # noisy vs original

# %%
original_img = cv2.imread('./sharp/7.jpg', cv2.IMREAD_GRAYSCALE)
blurred_img = cv2.imread('./noise/gaussian_noisy.jpg', cv2.IMREAD_GRAYSCALE)

print("PSNR:", calculate_psnr(original_img, blurred_img))
print("SSIM:", calculate_ssim(original_img, blurred_img))
print("MSE:", calculate_mse(original_img, blurred_img))
print("NCC:", calculate_ncc(original_img, blurred_img))
print("GMSD:", calculate_gmsd(original_img, blurred_img))
print("VIF:", calculate_vif(original_img, blurred_img))
print("FSIM:", calculate_fsim(original_img, blurred_img))
# Out:
# PSNR: 20.255916492349108
# SSIM: 0.20471616088149933
# MSE: 613.0398575498575
# NCC: 0.9130192558516156
# GMSD: 0.0757011837824687
# VIF: 0.0032201325385556503
# FSIM: 0.21155773

# %% [markdown]
# # only Gaussian vs original

# %%
original_img = cv2.imread('./sharp/7.jpg', cv2.IMREAD_GRAYSCALE)
blurred_img = cv2.imread('./result/only_Gaussian.jpg', cv2.IMREAD_GRAYSCALE)

print("PSNR:", calculate_psnr(original_img, blurred_img))
print("SSIM:", calculate_ssim(original_img, blurred_img))
print("MSE:", calculate_mse(original_img, blurred_img))
print("NCC:", calculate_ncc(original_img, blurred_img))
print("GMSD:", calculate_gmsd(original_img, blurred_img))
print("VIF:", calculate_vif(original_img, blurred_img))
print("FSIM:", calculate_fsim(original_img, blurred_img))
# Out:
# PSNR: 29.081201197892504
# SSIM: 0.690407106918159
# MSE: 80.34525641025641
# NCC: 0.9871463312078532
# GMSD: 0.027442218963702653
# VIF: 0.02768816985579704
# FSIM: 0.3913554

# %% [markdown]
# # GA+Gaussian vs original

# %%
original_img = cv2.imread('./sharp/7.jpg', cv2.IMREAD_GRAYSCALE)
blurred_img = cv2.imread('./result/GA_Gaussian.jpg', cv2.IMREAD_GRAYSCALE)

print("PSNR:", calculate_psnr(original_img, blurred_img))
print("SSIM:", calculate_ssim(original_img, blurred_img))
print("MSE:", calculate_mse(original_img, blurred_img))
print("NCC:", calculate_ncc(original_img, blurred_img))
print("GMSD:", calculate_gmsd(original_img, blurred_img))
print("VIF:", calculate_vif(original_img, blurred_img))
print("FSIM:", calculate_fsim(original_img, blurred_img))
# Out:
# PSNR: 29.24567218588478
# SSIM: 0.7553739690765908
# MSE: 77.35940883190884
# NCC: 0.9876686828129491
# GMSD: 0.027652224572130648
# VIF: 0.028053607946252404
# FSIM: 0.40505475

# %% [markdown]
# # GA+Gaussian vs only Gaussian

# %%
original_img = cv2.imread('./result/only_Gaussian.jpg', cv2.IMREAD_GRAYSCALE)
blurred_img = cv2.imread('./result/GA_Gaussian.jpg', cv2.IMREAD_GRAYSCALE)

print("PSNR:", calculate_psnr(original_img, blurred_img))
print("SSIM:", calculate_ssim(original_img, blurred_img))
print("MSE:", calculate_mse(original_img, blurred_img))
print("NCC:", calculate_ncc(original_img, blurred_img))
print("GMSD:", calculate_gmsd(original_img, blurred_img))
print("VIF:", calculate_vif(original_img, blurred_img))
print("FSIM:", calculate_fsim(original_img, blurred_img))
# Out:
# PSNR: 41.75876175170991
# SSIM: 0.9651512669627264
# MSE: 4.337147435897436
# NCC: 0.9992892124475374
# GMSD: 0.007904686183816446
# VIF: 0.2620876691401253
# FSIM: 0.7218432
